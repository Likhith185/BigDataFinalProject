# %%
import collections
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
f = open('C:\\Python37\\Scripts\\BigDataProject\\Cleaned\\a94amj.txt','r')
words = [x for y in [l.split() for l in f.readlines()] for x in y]
data = sorted([(w, words.count(w)) for w in set(words)], key = lambda x:x[1], reverse=True)[:5] 

print(data)

most_words = [x[0] for x in data]
times_used = [int(x[1]) for x in data]
print(most_words)
print(times_used)
# Out:
# [('human', 113), ('resource', 102), ('systems', 72), ('control', 56), ('management', 51)]
# ['human', 'resource', 'systems', 'control', 'management']
# [113, 102, 72, 56, 51]

# %%
import matplotlib.pyplot as plt

words = [('human', 113), ('resource', 102), ('systems', 72), ('control', 56), ('management', 51)]
sizes, labels = [i[1] for i in words],[i[0] for i in words]
plt.pie(sizes, labels=labels,autopct='%1.1i%%')
plt.show()

# %%
f = open('C:\\Python37\\Scripts\\BigDataProject\\Cleaned\\adg08hrm.txt','r')
words = [x for y in [l.split() for l in f.readlines()] for x in y]
data = sorted([(w, words.count(w)) for w in set(words)], key = lambda x:x[1], reverse=True)[:5] 

print(data)

most_words = [x[0] for x in data]
times_used = [int(x[1]) for x in data]
print(most_words)
print(times_used)
# Out:
# [('hrm', 137), ('practices', 127), ('performance', 111), ('strategic', 106), ('human', 86)]
# ['hrm', 'practices', 'performance', 'strategic', 'human']
# [137, 127, 111, 106, 86]

# %%
import matplotlib.pyplot as plt

words = [('hrm', 137), ('practices', 127), ('performance', 111), ('strategic', 106), ('human', 86)]
sizes, labels = [i[1] for i in words],[i[0] for i in words]
plt.pie(sizes, labels=labels,autopct='%1.1i%%')
plt.show()
