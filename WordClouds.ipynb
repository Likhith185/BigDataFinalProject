# %%
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
a = open("C:\\Python37\\Scripts\\BigDataProject\\Cleaned\\a94amj.txt", encoding="utf8").read()
b = open("C:\\Python37\\Scripts\\BigDataProject\\Cleaned\\adg08hrm.txt", encoding="utf8").read()
c = open("C:\\Python37\\Scripts\\BigDataProject\\Cleaned\\bnk00jbr.txt", encoding="utf8").read()
d = open("C:\\Python37\\Scripts\\BigDataProject\\Cleaned\\bm05jbe.txt", encoding="utf8").read()
e = open("C:\\Python37\\Scripts\\BigDataProject\\Cleaned\\bw04jbr.txt", encoding="utf8").read()
f = open("C:\\Python37\\Scripts\\BigDataProject\\Cleaned\\ces06ee.txt", encoding="utf8").read()
g = open("C:\\Python37\\Scripts\\BigDataProject\\Cleaned\\ct05crr.txt", encoding="utf8").read()
h = open("C:\\Python37\\Scripts\\BigDataProject\\Cleaned\\d00jom.txt", encoding="utf8").read()
i = open("C:\\Python37\\Scripts\\BigDataProject\\Cleaned\\dd96amj.txt", encoding="utf8").read()
j = open("C:\\Python37\\Scripts\\BigDataProject\\Cleaned\\g03ijhrm.txt", encoding="utf8").read()
k = open("C:\\Python37\\Scripts\\BigDataProject\\Cleaned\\jd98jms.txt", encoding="utf8").read()
l = open("C:\\Python37\\Scripts\\BigDataProject\\Cleaned\\jv04amj.txt", encoding="utf8").read()
m = open("C:\\Python37\\Scripts\\BigDataProject\\Cleaned\\jy11bjir.txt", encoding="utf8").read()
n = open("C:\\Python37\\Scripts\\BigDataProject\\Cleaned\\lcy12ijebm.txt", encoding="utf8").read()
o = open("C:\\Python37\\Scripts\\BigDataProject\\Cleaned\\lpaf13jcp.txt", encoding="utf8").read()
p = open("C:\\Python37\\Scripts\\BigDataProject\\Cleaned\\m10bse.txt", encoding="utf8").read()
q = open("C:\\Python37\\Scripts\\BigDataProject\\Cleaned\\pb00amj.txt", encoding="utf8").read()
r = open("C:\\Python37\\Scripts\\BigDataProject\\Cleaned\\rffa98jom.txt", encoding="utf8").read()
s = open("C:\\Python37\\Scripts\\BigDataProject\\Cleaned\\sz09amj.txt", encoding="utf8").read()
t = open("C:\\Python37\\Scripts\\BigDataProject\\Cleaned\\w02jom.txt", encoding="utf8").read()

# %%
wc = WordCloud(background_color="white") #,mask=mask)
wc.generate(a)
wc1 = WordCloud(background_color="white") #,mask=mask)
wc1.generate(b)
wc2 = WordCloud(background_color="white") #,mask=mask)
wc2.generate(c)
wc3 = WordCloud(background_color="white") #,mask=mask)
wc3.generate(d)
wc4 = WordCloud(background_color="white") #,mask=mask)
wc4.generate(e)
wc5 = WordCloud(background_color="white") #,mask=mask)
wc5.generate(f)
wc6 = WordCloud(background_color="white") #,mask=mask)
wc6.generate(g)
wc7 = WordCloud(background_color="white") #,mask=mask)
wc7.generate(h)
wc8 = WordCloud(background_color="white") #,mask=mask)
wc8.generate(i)
wc9 = WordCloud(background_color="white") #,mask=mask)
wc9.generate(j)
wc10 = WordCloud(background_color="white") #,mask=mask)
wc10.generate(k)
wc11 = WordCloud(background_color="white") #,mask=mask)
wc11.generate(l)
wc12 = WordCloud(background_color="white") #,mask=mask)
wc12.generate(m)
wc13 = WordCloud(background_color="white") #,mask=mask)
wc13.generate(n)
wc14 = WordCloud(background_color="white") #,mask=mask)
wc14.generate(o)
wc15 = WordCloud(background_color="white") #,mask=mask)
wc15.generate(p)
wc16 = WordCloud(background_color="white") #,mask=mask)
wc16.generate(q)
wc17 = WordCloud(background_color="white") #,mask=mask)
wc17.generate(r)
wc18 = WordCloud(background_color="white") #,mask=mask)
wc18.generate(s)
wc19 = WordCloud(background_color="white") #,mask=mask)
wc19.generate(t)

fig, axes = plt.subplots(nrows=5, ncols=4, figsize=(20, 20))

axes[0, 0].set_title("a94amj")
axes[0,0].axis("on")
axes[0,0].imshow(wc)

axes[0, 1].set_title("adg08hrm")
axes[0,1].axis("on")
axes[0,1].imshow(wc1)

axes[0, 2].set_title("bnk00jbr")
axes[0,2].axis("on")
axes[0,2].imshow(wc2)

axes[0, 3].set_title("bm05jbe")
axes[0,3].axis("on")
axes[0,3].imshow(wc3)

axes[1, 0].set_title("bw04jbr")
axes[1,0].axis("on")
axes[1,0].imshow(wc4)

axes[1, 1].set_title("ces06ee")
axes[1,1].axis("on")
axes[1,1].imshow(wc5)

axes[1, 2].set_title("ct05crr")
axes[1,2].axis("on")
axes[1,2].imshow(wc6)

axes[1, 3].set_title("d00jom")
axes[1,3].axis("on")
axes[1,3].imshow(wc7)

axes[2, 0].set_title("dd96amj")
axes[2,0].axis("on")
axes[2,0].imshow(wc8)

axes[2, 1].set_title("g03ijhrm")
axes[2,1].axis("on")
axes[2,1].imshow(wc9)

axes[2, 2].set_title("jd98jms")
axes[2,2].axis("on")
axes[2,2].imshow(wc10)

axes[2, 3].set_title("jv04amj")
axes[2,3].axis("on")
axes[2,3].imshow(wc11)

axes[3, 0].set_title("jy11bjir")
axes[3,0].axis("on")
axes[3,0].imshow(wc12)

axes[3, 1].set_title("lcy12ijebm")
axes[3,1].axis("on")
axes[3,1].imshow(wc13)

axes[3, 2].set_title("lpaf13jcp")
axes[3,2].axis("on")
axes[3,2].imshow(wc14)

axes[3, 3].set_title("m10bse")
axes[3,3].axis("on")
axes[3,3].imshow(wc15)

axes[4, 0].set_title("pb00amj")
axes[4,0].axis("on")
axes[4,0].imshow(wc16)

axes[4, 1].set_title("rffa98jom")
axes[4,1].axis("on")
axes[4,1].imshow(wc17)

axes[4, 2].set_title("sz09amj")
axes[4,2].axis("on")
axes[4,2].imshow(wc18)

axes[4, 3].set_title("w02jom")
axes[4,3].axis("on")
axes[4,3].imshow(wc19)


plt.show()
